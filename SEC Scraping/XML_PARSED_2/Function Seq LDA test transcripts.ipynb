# %%
import os, gensim

def iter_documents(top_directory):
    """Iterate over all documents, yielding a document (=list of utf8 tokens) at a time."""
    for root, dirs, files in os.walk(top_directory):
        for file in filter(lambda file: file.endswith('.txt'), files):
            document = open(os.path.join(root, file), encoding='utf8').read() # read the entire document, as one big string
            yield gensim.utils.tokenize(document, lower=True) # or whatever tokenization suits you

class MyCorpus(object):
    def __init__(self, top_dir):
        self.top_dir = top_dir
        self.dictionary = gensim.corpora.Dictionary(iter_documents(top_dir))
        self.dictionary.filter_extremes(no_below=1, keep_n=30000) # check API docs for pruning params

    def __iter__(self):
        for tokens in iter_documents(self.top_dir):
            yield self.dictionary.doc2bow(tokens)

# %%
import logging
import os
from gensim import corpora, utils
from gensim.models.wrappers.dtmmodel import DtmModel
import numpy as np
import glob

import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def get_topics(folder, num_topics, show_top):
    corpus = MyCorpus(folder) # create a dictionary
    
    os.environ['DTM_PATH'] = r"dtm-win64.exe"

    if not os.environ.get('DTM_PATH', None):
        raise ValueError("SKIP: You need to set the DTM path")
        
    time_seq = []

    for year in range(2010, 2021):
        docs_num = len(glob.glob(folder + "\\" + str(year) + "*"))
        print(f"Year {year} has {docs_num} documents")
        time_seq.append(docs_num)
        
    dtm_path = os.environ['DTM_PATH']
    
    model = DtmModel(dtm_path, corpus, time_seq, num_topics=num_topics,
                 id2word=corpus.dictionary, initialize_lda=True)
    
    topic_list = []

    for id in range(num_topics):
        topic = [model.show_topic(topicid=id, time=time, topn=show_top) for time in range(len(time_seq))]
        topic_list.append(topic)
        
    x = range(2010,2010+len(time_seq))

    for index, topic in enumerate(topic_list):
        plt.title("Topic " + str(index+1))

        for word in range(show_top):
            prob = [sub[word] for sub in topic]
            values = [probability[0] for probability in prob]
            plt.plot(x, values, label = prob[0][1])

        plt.xticks(np.arange(2010, 2020, step = 1))
        plt.ylabel("Word Distribution")
        plt.xlabel("Year")
        plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

        plt.show()
        
    for topic in range(num_topics):
        print(f'Topic {topic}')
        print(model.print_topics()[topic])
        print()
        
    return(model)

# %% [markdown]
# https://markroxor.github.io/gensim/static/notebooks/ldaseqmodel.html

# %%
# %%time
trans_amazon = get_topics('Transcripts', num_topics = 12, show_top = 10)
# Out:
# Year 2010 has 393 documents
# Year 2011 has 538 documents
# Year 2012 has 592 documents
# Year 2013 has 724 documents
# Year 2014 has 540 documents
# Year 2015 has 670 documents
# Year 2016 has 659 documents
# Year 2017 has 739 documents
# Year 2018 has 747 documents
# Year 2019 has 869 documents
# Year 2020 has 274 documents
# Topic 0
# 0.042*income + 0.041*increase + 0.036*segment + 0.036*expense + 0.028*tax + 0.027*impact + 0.027*revenue + 0.025*currency + 0.019*inventory + 0.013*operating
#
# Topic 1
# 0.029*inflation + 0.028*market + 0.025*price + 0.015*household + 0.014*environment + 0.012*cost + 0.012*tonnage + 0.011*consumer + 0.010*deflation + 0.009*competitor
#
# Topic 2
# 0.060*brand + 0.042*product + 0.038*category + 0.038*food + 0.026*cost + 0.020*price + 0.018*area + 0.017*sell + 0.015*quality + 0.013*apparel
#
# Topic 3
# 0.043*customer + 0.021*category + 0.015*season + 0.014*holiday + 0.013*brand + 0.012*assortment + 0.010*product + 0.008*experience + 0.008*home + 0.008*plan
#
# Topic 4
# 0.078*margin + 0.028*investment + 0.017*seem + 0.016*mix + 0.013*price + 0.012*category + 0.012*couple + 0.012*follow + 0.011*understand + 0.011*sense
#
# Topic 5
# 0.027*content + 0.027*capacity + 0.022*revenue + 0.020*service + 0.020*fulfillment + 0.020*selection + 0.020*center + 0.016*medium + 0.015*device + 0.014*cost
#
# Topic 6
# 0.026*price + 0.019*a + 0.014*couple + 0.012*country + 0.012*keep + 0.012*come + 0.010*help + 0.010*anything + 0.010*impact + 0.010*view
#
# Topic 7
# 0.033*increase + 0.017*price + 0.015*income + 0.015*expense + 0.013*drive + 0.013*member + 0.012*traffic + 0.012*fuel + 0.011*market + 0.010*decline
#
# Topic 8
# 0.018*margin + 0.016*fuel + 0.015*return + 0.014*performance + 0.014*increase + 0.013*capital + 0.012*cash + 0.012*shareholder + 0.011*investment + 0.011*plan
#
# Topic 9
# 0.027*increase + 0.026*gas + 0.021*margin + 0.016*inflation + 0.016*membership + 0.016*member + 0.016*impact + 0.015*income + 0.012*dollar + 0.012*year
#
# Topic 10
# 0.041*income + 0.041*increase + 0.037*expense + 0.035*segment + 0.028*tax + 0.028*impact + 0.026*revenue + 0.025*currency + 0.019*inventory + 0.013*operating
#
# Topic 11
# 0.031*market + 0.030*inflation + 0.026*price + 0.014*household + 0.013*environment + 0.012*cost + 0.011*consumer + 0.011*tonnage + 0.009*competitor + 0.009*deflation
#
# Wall time: 8min 52s

# %%
lda_amazon = get_topics('AMZN_XML', num_topics = 10, show_top = 10)
# Out:
# Year 2010 has 11 documents
# Year 2011 has 13 documents
# Year 2012 has 16 documents
# Year 2013 has 10 documents
# Year 2014 has 16 documents
# Year 2015 has 11 documents
# Year 2016 has 13 documents
# Year 2017 has 17 documents
# Year 2018 has 15 documents
# Year 2019 has 15 documents
# Topic 0
# 0.056*role + 0.054*publisher + 0.045*codification + 0.043*ie + 0.031*el + 0.026*topic + 0.025*taxonomy + 0.022*interim + 0.022*hierarchy + 0.020*solid
#
# Topic 1
# 0.030*mo + 0.030*mi + 0.025*ma + 0.025*mu + 0.013*wo + 0.012*ox + 0.012*ho + 0.011*se + 0.011*fi + 0.011*hi
#
# Topic 2
# 0.047*solid + 0.033*overflow + 0.033*hidden + 0.033*role + 0.032*height + 0.030*publisher + 0.030*topic + 0.028*codification + 0.023*prefix + 0.020*double
#
# Topic 3
# 0.078*trustee + 0.048*shall + 0.048*indenture + 0.026*prospectus + 0.025*redemption + 0.015*default + 0.014*agent + 0.012*holder + 0.012*supplement + 0.008*depositary
#
# Topic 4
# 0.027*proxy + 0.020*your + 0.018*vote + 0.014*director + 0.013*audit + 0.013*shareholder + 0.011*leadership + 0.008*voting + 0.008*independent + 0.008*governance
#
# Topic 5
# 0.057*role + 0.048*publisher + 0.045*solid + 0.039*codification + 0.037*topic + 0.026*prefix + 0.024*double + 0.021*overflow + 0.020*hidden + 0.019*subparagraph
#
# Topic 6
# 0.194*span + 0.048*role + 0.025*ref + 0.024*overflow + 0.023*hidden + 0.022*topic + 0.021*publisher + 0.021*en + 0.021*codification + 0.019*solid
#
# Topic 7
# 0.059*solid + 0.046*authoritative + 0.036*iso + 0.032*ie + 0.030*el + 0.029*role + 0.028*double + 0.025*publisher + 0.012*duration + 0.012*monetary
#
# Topic 8
# 0.099*shall + 0.046*administrator + 0.019*participant + 0.016*grant + 0.016*incentive + 0.015*award + 0.013*director + 0.010*parent + 0.010*optionee + 0.010*action
#
# Topic 9
# 0.109*fae + 0.055*vat + 0.043*hidden + 0.042*overflow + 0.033*el + 0.023*po + 0.019*en + 0.018*publisher + 0.017*role + 0.016*fen

# %%
lda_costco = get_topics('COST_XML', num_topics = 10, show_top = 10)
# Out:
# Year 2010 has 9 documents
# Year 2011 has 7 documents
# Year 2012 has 14 documents
# Year 2013 has 8 documents
# Year 2014 has 9 documents
# Year 2015 has 14 documents
# Year 2016 has 9 documents
# Year 2017 has 12 documents
# Year 2018 has 7 documents
# Year 2019 has 18 documents
# Topic 0
# 0.101*solid + 0.053*double + 0.041*authoritative + 0.037*iso + 0.036*justify + 0.026*monetary + 0.026*duration + 0.022*vat + 0.018*debit + 0.017*po
#
# Topic 1
# 0.108*participant + 0.061*administrator + 0.017*deferral + 0.014*contents + 0.013*salary + 0.013*loan + 0.012*death + 0.011*discretionary + 0.011*beneficiary + 0.010*trustee
#
# Topic 2
# 0.089*codification + 0.048*topic + 0.042*taxonomy + 0.036*hierarchy + 0.036*removed + 0.036*prefix + 0.035*help + 0.034*subparagraph + 0.030*solid + 0.023*vat
#
# Topic 3
# 0.045*your + 0.029*confidential + 0.011*conflict + 0.010*cardholder + 0.008*marketing + 0.007*please + 0.006*response + 0.006*network + 0.006*thirty + 0.006*portfolio
#
# Topic 4
# 0.076*prefix + 0.058*topic + 0.056*codification + 0.054*solid + 0.035*duration + 0.032*subparagraph + 0.029*double + 0.029*height + 0.023*hidden + 0.017*instant
#
# Topic 5
# 0.019*meeting + 0.019*prospectus + 0.013*vote + 0.009*series + 0.008*trustee + 0.008*contents + 0.008*supplement + 0.008*proposal + 0.007*your + 0.006*bonus
#
# Topic 6
# 0.177*span + 0.050*ref + 0.044*documentation + 0.026*prefix + 0.021*duration + 0.021*topic + 0.021*codification + 0.017*null + 0.016*finance + 0.014*taxonomy
#
# Topic 7
# 0.110*hidden + 0.074*fae + 0.071*vat + 0.041*decoration + 0.033*height + 0.032*cap + 0.031*po + 0.028*weight + 0.027*bold + 0.023*codification
#
# Topic 8
# 0.042*solid + 0.039*justify + 0.029*double + 0.027*topic + 0.025*receivables + 0.017*codification + 0.013*subparagraph + 0.011*vendor + 0.011*reinsurance + 0.011*unrecognized
#
# Topic 9
# 0.081*solid + 0.043*authoritative + 0.038*double + 0.023*duration + 0.017*iso + 0.015*vat + 0.012*noncontrolling + 0.011*subparagraph + 0.011*height + 0.011*po

# %%
lda_kroger = get_topics('KR_XML', num_topics = 10, show_top = 10)
# Out:
# Year 2010 has 20 documents
# Year 2011 has 15 documents
# Year 2012 has 23 documents
# Year 2013 has 20 documents
# Year 2014 has 26 documents
# Year 2015 has 19 documents
# Year 2016 has 19 documents
# Year 2017 has 22 documents
# Year 2018 has 17 documents
# Year 2019 has 25 documents
# Topic 0
# 0.079*role + 0.076*publisher + 0.046*link + 0.042*duration + 0.035*prefix + 0.034*codification + 0.030*comprehensive + 0.024*na + 0.023*topic + 0.021*weight
#
# Topic 1
# 0.708*serif + 0.038*display + 0.024*float + 0.020*height + 0.009*bold + 0.008*weight + 0.007*solid + 0.005*auto + 0.004*prefix + 0.004*role
#
# Topic 2
# 0.050*prospectus + 0.038*indenture + 0.029*depositary + 0.024*series + 0.021*preferred + 0.015*trustee + 0.015*supplement + 0.014*redemption + 0.009*contents + 0.009*therein
#
# Topic 3
# 0.013*bonus + 0.013*impairment + 0.009*lifo + 0.009*his + 0.008*incentive + 0.007*he + 0.007*vote + 0.007*proxy + 0.007*program + 0.005*grant
#
# Topic 4
# 0.062*medium + 0.044*role + 0.043*codification + 0.043*publisher + 0.026*taxonomy + 0.024*interim + 0.023*hierarchy + 0.022*removed + 0.022*help + 0.021*bu
#
# Topic 5
# 0.121*white + 0.060*role + 0.048*space + 0.031*weight + 0.028*publisher + 0.027*codification + 0.025*topic + 0.025*span + 0.024*hidden + 0.023*bold
#
# Topic 6
# 0.176*el + 0.162*ye + 0.060*solid + 0.058*height + 0.048*line + 0.048*vat + 0.022*weight + 0.022*bold + 0.021*float + 0.020*po
#
# Topic 7
# 0.069*borrower + 0.066*lender + 0.061*agent + 0.021*issuing + 0.018*advance + 0.016*borrowing + 0.014*revolving + 0.013*paying + 0.012*hereunder + 0.011*bid
#
# Topic 8
# 0.259*medium + 0.055*bold + 0.055*weight + 0.040*tu + 0.036*solid + 0.032*height + 0.032*te + 0.023*ta + 0.023*ye + 0.016*authoritative
#
# Topic 9
# 0.105*master + 0.061*contents + 0.033*collective + 0.024*mutual + 0.023*observable + 0.022*duration + 0.021*synthetic + 0.018*measurement + 0.018*active + 0.016*administrator

# %%
lda_target = get_topics('TGT_XML', num_topics = 10, show_top = 10)
# Out:
# Year 2010 has 21 documents
# Year 2011 has 15 documents
# Year 2012 has 21 documents
# Year 2013 has 14 documents
# Year 2014 has 18 documents
# Year 2015 has 18 documents
# Year 2016 has 19 documents
# Year 2017 has 15 documents
# Year 2018 has 12 documents
# Year 2019 has 15 documents
# Topic 0
# 0.048*tu + 0.038*bu + 0.030*shall + 0.021*ta + 0.020*ye + 0.018*codification + 0.015*te + 0.014*role + 0.013*publisher + 0.012*borrower
#
# Topic 1
# 0.149*punctuation + 0.149*wrap + 0.147*simple + 0.062*medium + 0.024*solid + 0.018*bu + 0.016*bold + 0.016*weight + 0.015*publisher + 0.015*codification
#
# Topic 2
# 0.112*bold + 0.110*weight + 0.077*solid + 0.065*fae + 0.061*vat + 0.045*el + 0.036*hidden + 0.034*overflow + 0.015*definition + 0.015*ie
#
# Topic 3
# 0.019*proxy + 0.018*vote + 0.016*director + 0.016*meeting + 0.015*incentive + 0.015*shareholder + 0.014*you + 0.012*your + 0.010*award + 0.009*grant
#
# Topic 4
# 0.176*solid + 0.070*publisher + 0.065*role + 0.038*prefix + 0.029*codification + 0.027*topic + 0.026*duration + 0.025*link + 0.019*subparagraph + 0.019*na
#
# Topic 5
# 0.161*th + 0.141*height + 0.022*solid + 0.022*justify + 0.019*authoritative + 0.017*role + 0.016*definition + 0.015*publisher + 0.014*white + 0.012*user
#
# Topic 6
# 0.057*shall + 0.053*participant + 0.023*administrator + 0.020*pool + 0.017*claim + 0.016*employment + 0.015*deferral + 0.009*beneficiary + 0.009*employee + 0.008*review
#
# Topic 7
# 0.381*medium + 0.066*solid + 0.046*weight + 0.046*bold + 0.033*wrap + 0.030*bu + 0.030*tu + 0.029*simple + 0.027*punctuation + 0.020*ta
#
# Topic 8
# 0.073*height + 0.061*el + 0.040*te + 0.040*role + 0.037*publisher + 0.026*codification + 0.021*th + 0.019*subparagraph + 0.018*definition + 0.018*bu
#
# Topic 9
# 0.047*prospectus + 0.030*depositary + 0.027*supplement + 0.023*holder + 0.017*redemption + 0.016*indenture + 0.015*agent + 0.015*maturity + 0.013*floating + 0.011*qualified

# %%
lda_walmart = get_topics('WMT_XML', num_topics = 10, show_top = 10)
# Out:
# Year 2010 has 24 documents
# Year 2011 has 20 documents
# Year 2012 has 13 documents
# Year 2013 has 20 documents
# Year 2014 has 27 documents
# Year 2015 has 15 documents
# Year 2016 has 16 documents
# Year 2017 has 27 documents
# Year 2018 has 26 documents
# Year 2019 has 26 documents
# Topic 0
# 0.025*participant + 0.018*restricted + 0.017*solid + 0.015*award + 0.014*incentive + 0.012*retirement + 0.011*deferral + 0.011*valuation + 0.010*vesting + 0.010*minimum
#
# Topic 1
# 0.113*span + 0.069*role + 0.032*solid + 0.027*ref + 0.027*publisher + 0.026*topic + 0.026*codification + 0.024*hidden + 0.023*overflow + 0.023*label
#
# Topic 2
# 0.101*codification + 0.061*role + 0.060*publisher + 0.055*topic + 0.038*removed + 0.037*hierarchy + 0.037*help + 0.037*interim + 0.037*previous + 0.032*taxonomy
#
# Topic 3
# 0.113*overflow + 0.101*hidden + 0.093*middle + 0.046*codification + 0.039*solid + 0.037*topic + 0.037*role + 0.032*publisher + 0.029*height + 0.028*weight
#
# Topic 4
# 0.040*flow + 0.040*roi + 0.027*press + 0.018*diluted + 0.015*fourth + 0.015*depreciation + 0.013*sam + 0.011*rent + 0.011*said + 0.009*strong
#
# Topic 5
# 0.022*incentive + 0.019*proxy + 0.017*his + 0.015*director + 0.014*contents + 0.014*meeting + 0.013*vote + 0.010*award + 0.009*target + 0.008*your
#
# Topic 6
# 0.155*fae + 0.064*fen + 0.061*hidden + 0.060*ie + 0.057*overflow + 0.055*cap + 0.050*vat + 0.020*middle + 0.019*decoration + 0.018*height
#
# Topic 7
# 0.062*role + 0.056*publisher + 0.039*solid + 0.028*duration + 0.022*double + 0.017*link + 0.015*article + 0.013*noncontrolling + 0.013*derivative + 0.012*subparagraph
#
# Topic 8
# 0.053*indenture + 0.046*prospectus + 0.021*trustee + 0.017*supplement + 0.014*agent + 0.012*depositary + 0.010*promissory + 0.010*hereof + 0.009*maturity + 0.009*default
#
# Topic 9
# 0.115*authoritative + 0.065*iso + 0.064*solid + 0.035*unit + 0.019*height + 0.017*monetary + 0.016*double + 0.015*meeting + 0.014*director + 0.011*vat
