# %%
import os, gensim

def iter_documents(top_directory):
    """Iterate over all documents, yielding a document (=list of utf8 tokens) at a time."""
    for root, dirs, files in os.walk(top_directory):
        for file in filter(lambda file: file.endswith('.txt'), files):
            document = open(os.path.join(root, file), encoding='utf8').read() # read the entire document, as one big string
            yield gensim.utils.tokenize(document, lower=True) # or whatever tokenization suits you

class MyCorpus(object):
    def __init__(self, top_dir):
        self.top_dir = top_dir
        self.dictionary = gensim.corpora.Dictionary(iter_documents(top_dir))
        self.dictionary.filter_extremes(no_below=1, keep_n=30000) # check API docs for pruning params

    def __iter__(self):
        for tokens in iter_documents(self.top_dir):
            yield self.dictionary.doc2bow(tokens)

# %%
import logging
import os
from gensim import corpora, utils
from gensim.models.wrappers.dtmmodel import DtmModel
import numpy as np
import glob

def get_topics(folder, num_topics, show_top):
    corpus = MyCorpus(folder) # create a dictionary
    
    os.environ['DTM_PATH'] = r"dtm-win64.exe"

    if not os.environ.get('DTM_PATH', None):
        raise ValueError("SKIP: You need to set the DTM path")

# %%
time_seq = []

for year in range(2010, 2020):
    docs_num = len(glob.glob(folder + "\\" + str(year) + "*"))
    print(f"Year {year} has {docs_num} documents")
    time_seq.append(docs_num)
# Out:
# Year 2010 has 24 documents
# Year 2011 has 20 documents
# Year 2012 has 13 documents
# Year 2013 has 20 documents
# Year 2014 has 27 documents
# Year 2015 has 15 documents
# Year 2016 has 16 documents
# Year 2017 has 27 documents
# Year 2018 has 26 documents
# Year 2019 has 26 documents

# %%
time_seq
# Out:
# [24, 20, 13, 20, 27, 15, 16, 27, 26, 26]

# %%
dtm_path = os.environ['DTM_PATH']

# %%
num_topics = 10

model = DtmModel(dtm_path, corpus, time_seq, num_topics=num_topics,
                 id2word=corpus.dictionary, initialize_lda=True)

# %%
topic_list = []
show_top = 10

for id in range(num_topics):
    topic = [model.show_topic(topicid=id, time=time, topn=show_top) for time in range(len(time_seq))]
    topic_list.append(topic)

# %%
topic_list[0]
# Out:
# [[(0.052210286527923824, 'shareholder'),
#   (0.03982755874446111, 'meeting'),
#   (0.034800754608603934, 'director'),
#   (0.014903210567032584, 'proceeding'),
#   (0.01471527668854417, 'registrable'),
#   (0.011542832255058607, 'days'),
#   (0.011446836207442988, 'certificate'),
#   (0.011018940059997368, 'indemnification'),
#   (0.010828024872125006, 'vote'),
#   (0.010797777893110098, 'agent')],
#  [(0.049330755783192945, 'shareholder'),
#   (0.044526616365072526, 'meeting'),
#   (0.03211054129747182, 'director'),
#   (0.014037604257191746, 'proceeding'),
#   (0.013909465061239754, 'registrable'),
#   (0.011915678107421052, 'days'),
#   (0.011292130588284934, 'certificate'),
#   (0.011012022106345483, 'vote'),
#   (0.010721720075514354, 'indemnification'),
#   (0.010557144093511021, 'special')],
#  [(0.05346638526020671, 'meeting'),
#   (0.03487049434446055, 'shareholder'),
#   (0.029888449345164856, 'director'),
#   (0.013265475595178164, 'proceeding'),
#   (0.012122633982428969, 'days'),
#   (0.011880842959420995, 'special'),
#   (0.011156149420567953, 'vote'),
#   (0.010799810563078683, 'certificate'),
#   (0.010677999587339306, 'indemnification'),
#   (0.009980928367690416, 'request')],
#  [(0.06323433839824091, 'meeting'),
#   (0.0273101517276752, 'director'),
#   (0.022367842615345978, 'shareholder'),
#   (0.01334192040535319, 'special'),
#   (0.012560174741843292, 'proceeding'),
#   (0.012203861711363928, 'days'),
#   (0.0110669583230395, 'electronic'),
#   (0.011065518520468852, 'vote'),
#   (0.010660889498301438, 'indemnification'),
#   (0.010135798659731127, 'certificate')],
#  [(0.06813675493384812, 'meeting'),
#   (0.024026381871874843, 'director'),
#   (0.015400289269585985, 'shareholder'),
#   (0.014091670679169452, 'special'),
#   (0.012134140951890532, 'days'),
#   (0.012013244000258697, 'electronic'),
#   (0.01189613976344154, 'proceeding'),
#   (0.01072295571757971, 'article'),
#   (0.010635130234743956, 'vote'),
#   (0.010528062775638482, 'indemnification')],
#  [(0.05967909068698962, 'meeting'),
#   (0.020589602285193437, 'director'),
#   (0.013143065223474549, 'shareholder'),
#   (0.012442042308679417, 'special'),
#   (0.011682176102518612, 'proceeding'),
#   (0.011351510085621387, 'days'),
#   (0.01060877935875996, 'electronic'),
#   (0.01060515442314173, 'article'),
#   (0.01008827344252342, 'indemnification'),
#   (0.009720801563758683, 'vote')],
#  [(0.04694891066471936, 'meeting'),
#   (0.0174557572115639, 'director'),
#   (0.012599044144690461, 'shareholder'),
#   (0.011572056843544112, 'proceeding'),
#   (0.01075368250472501, 'purchaser'),
#   (0.010336905151742634, 'days'),
#   (0.010238815158691189, 'special'),
#   (0.010074436028711798, 'article'),
#   (0.010070683348351537, 'claim'),
#   (0.009752904935443766, 'indemnification')],
#  [(0.03552567097989912, 'meeting'),
#   (0.016241138751289443, 'purchaser'),
#   (0.014842780789278528, 'director'),
#   (0.012723645845675466, 'shareholder'),
#   (0.011736494245442364, 'claim'),
#   (0.011116257172622246, 'proceeding'),
#   (0.010486554743761494, 'seller'),
#   (0.00945991543860353, 'article'),
#   (0.009436926244307461, 'indemnification'),
#   (0.009276381110106304, 'days')],
#  [(0.027250871691044277, 'meeting'),
#   (0.02514135994262082, 'purchaser'),
#   (0.014981188007379695, 'seller'),
#   (0.013544416910758101, 'claim'),
#   (0.013068422693589533, 'shareholder'),
#   (0.01288886344035641, 'director'),
#   (0.010375107225588872, 'proceeding'),
#   (0.009934104463406054, 'representative'),
#   (0.00909778492809372, 'indemnification'),
#   (0.008782619827244792, 'article')],
#  [(0.025017351238464318, 'meeting'),
#   (0.023556175047431488, 'purchaser'),
#   (0.01465318190032547, 'seller'),
#   (0.013631998082777111, 'claim'),
#   (0.013157958020133377, 'shareholder'),
#   (0.012321181527542155, 'director'),
#   (0.010538298723702192, 'proceeding'),
#   (0.009900280869205094, 'representative'),
#   (0.00940654089217488, 'indemnification'),
#   (0.008726259178954962, 'article')]]

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = range(2010,2010+len(time_seq))

for index, topic in enumerate(topic_list):
    plt.title("Topic " + str(index+1))

    for word in range(show_top):
        prob = [sub[word] for sub in topic]
        values = [probability[0] for probability in prob]
        plt.plot(x, values, label = prob[0][1])
    
    plt.xticks(np.arange(2010, 2020, step = 1))
    plt.ylabel("Word Distribution")
    plt.xlabel("Year")
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    plt.show()

# %%
for topic in range(num_topics):
    print(f'Topic {topic}')
    print(model.print_topics()[topic])
    print()
# Out:
# Topic 0
# 0.052*shareholder + 0.040*meeting + 0.035*director + 0.015*proceeding + 0.015*registrable + 0.012*days + 0.011*certificate + 0.011*indemnification + 0.011*vote + 0.011*agent
#
# Topic 1
# 0.078*codification + 0.055*publisher + 0.054*role + 0.049*removed + 0.047*topic + 0.046*hierarchy + 0.045*previous + 0.045*help + 0.042*interim + 0.037*taxonomy
#
# Topic 2
# 0.088*role + 0.082*span + 0.038*publisher + 0.034*solid + 0.031*topic + 0.029*ref + 0.029*codification + 0.025*label + 0.020*hidden + 0.020*overflow
#
# Topic 3
# 0.035*roi + 0.034*flow + 0.023*press + 0.015*diluted + 0.013*sam + 0.012*fourth + 0.012*depreciation + 0.009*rent + 0.009*said + 0.007*po
#
# Topic 4
# 0.304*middle + 0.117*overflow + 0.105*hidden + 0.032*solid + 0.024*bold + 0.024*weight + 0.020*height + 0.019*topic + 0.017*double + 0.012*role
#
# Topic 5
# 0.059*role + 0.052*publisher + 0.044*solid + 0.026*authoritative + 0.024*duration + 0.022*double + 0.017*iso + 0.015*article + 0.015*link + 0.013*derivative
#
# Topic 6
# 0.076*indenture + 0.032*prospectus + 0.023*trustee + 0.018*depositary + 0.017*hereof + 0.017*promissory + 0.014*agent + 0.011*underwriting + 0.011*definitive + 0.010*certificate
#
# Topic 7
# 0.038*solid + 0.021*authoritative + 0.017*participant + 0.014*height + 0.014*unit + 0.013*restricted + 0.011*award + 0.010*double + 0.009*incentive + 0.009*retirement
#
# Topic 8
# 0.021*incentive + 0.019*proxy + 0.017*his + 0.014*director + 0.014*contents + 0.013*vote + 0.012*meeting + 0.011*award + 0.009*target + 0.008*your
#
# Topic 9
# 0.069*prospectus + 0.031*supplement + 0.022*indenture + 0.018*trustee + 0.016*contents + 0.015*premium + 0.014*your + 0.013*redemption + 0.013*maturity + 0.012*agent
