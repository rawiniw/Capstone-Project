# %%
import PyPDF2 
import textract
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
##write a for loop to open many files

#to parse one file:
filename = 'Walmart-2019-AR-Final.pdf' 

pdfFileObj = open(filename,'rb')

#The pdfReader variable is a readable object that will be parsed
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

#discerning the number of pages will allow us to parse through all the pages
num_pages = pdfReader.numPages
count = 0
text = ""

while count < num_pages:
    pageObj = pdfReader.getPage(count)
    count +=1
    text += pageObj.extractText()
    
#This if statement exists to check if the above library returned words. It's done because PyPDF2 cannot read scanned files.
if text != "":
    text = text
#If the above returns as False, we run the OCR library textract to #convert scanned/image based PDF files into text
else:
    text = textract.process(fileurl, method='tesseract', language='eng')
    
#text variable contains all the text derived from our PDF file.
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]

# %%
# print(text)

# %%
#tokenize into individual words
tokens = word_tokenize(text)

punctuations = ['(',')',';',':','[',']',',','.',"''"]

stop_words = stopwords.words('english')

#Return a list of words that are NOT IN stop_words and NOT IN punctuations.
keywords = [word for word in tokens if not word in stop_words and not word in punctuations]

# %%
# print(keywords)

# %%
from collections import Counter

freq = Counter(keywords)
print(freq)
# Out:
# Counter({'$': 740, 'Company': 431, 'fiscal': 333, '%': 324, "'s": 317, '2019': 306, 'The': 273, '2018': 258, '``': 257, 'Walmart': 246, 'sales': 219, 'income': 217, 'net': 210, 'U.S.': 202, 'billion': 201, 'financial': 173, 'tax': 171, 'cash': 165, 'assets': 143, 'operations': 138, '1': 137, 'including': 137, 'may': 135, 'operating': 127, 'January': 126, 'January•31': 120, '31': 119, 'certain': 117, 'value': 112, 'related': 112, 'We': 110, 'eCommerce': 110, 'business': 102, 'could': 99, 'year': 95, 'changes': 93, 'information': 93, 'share': 89, 'debt': 89, 'Consolidated': 87, 'In': 86, 'stores': 86, 'period': 86, 'loss': 83, 'rate': 81, '2017': 81, 'results': 80, 'rates': 78, 'result': 77, 'due': 77, 'fair': 76, 'also': 74, 'retail': 74, 'customers': 73, 'Form': 73, 'million': 72, 'International': 71, 'As': 70, 'Financial': 69, 'Club': 66, 'Sam': 65, '—': 65, 'stock': 64, 'liabilities': 64, 'primarily': 64, 'interest': 63, 'cost': 62, 'segment': 62, 'based': 61, 'Statements': 61, 'affect': 61, 'recorded': 61, '10': 60, 'performance': 60, 'currency': 60, 'respectively': 60, 'Amounts': 60, 'merchandise': 59, '‡': 59, '2': 58, 'capital': 58, 'statements': 58, 'Our': 57, 'long-term': 57, 'well': 57, 'comparable': 57, 'millions': 57, 'market': 56, 'filed': 56, 'reporting': 56, 'laws': 56, 'taxes': 56, 'approximately': 56, 'impact': 54, 'Act': 54, 'change': 53, 'adversely': 53, 'markets': 51, 'following': 51, 'expenses': 50, 'clubs': 50, 'amounts': 50, 'matters': 50, 'future': 49, 'using': 49, 'sale': 49, 'costs': 49, 'included': 49, 'associates': 48, 'exchange': 48, 'effective': 48, 'increase': 47, 'us': 47, 'store': 47, 'accounting': 47, 'Report': 47, 'factors': 47, 'For': 46, 'Fiscal': 46, 'February': 46, 'generally': 46, 'credit': 46, 'These': 45, 'Inc.': 44, 'common': 44, 'management': 44, 'amount': 44, 'new': 43, 'products': 43, 'significant': 43, 'incorporated': 43, 'Ended': 43, 'include': 43, 'regulations': 43, 'subject': 42, 'activities': 42, 'control': 42, 'Total': 42, '3': 41, 'Officer': 41, 'reference': 41, 'materially': 41, 'United': 41, 'previous': 41, 'used': 41, 'years': 40, 'time': 40, 'compared': 40, 'made': 39, 'basis': 39, '10-K': 39, 'Annual': 39, 'countries': 39, 'current': 39, 'distribution': 39, 'Tax': 39, 'number': 38, 'per': 38, 'price': 38, 'deferred': 38, 'Flipkart': 38, 'Exhibit': 38, 'growth': 37, 'Chief': 37, 'March': 37, 'investment': 37, 'addition': 37, 'required': 37, 'earnings': 37, 'foreign': 37, 'payments': 37, 'includes': 37, 'units': 37, 'total': 36, 'Executive': 36, 'services': 36, 'ended': 36, 'consolidated': 36, 'facilities': 36, 'lease': 36, 'Note': 35, 'table': 35, 'internal': 35, 'Net': 35, '4': 34, 'make': 34, 'increased': 34, "'": 34, 'decrease': 34, 'segments': 34, 'suppliers': 34, 'Other': 34, 'unit': 34, 'financing': 34, 'Brazil': 33, 'expected': 33, 'impairment': 33, 'material': 33, 'Income': 33, 'position': 32, 'one': 32, 'would': 32, 'President': 32, 'expense': 32, 'additional': 32, 'comprehensive': 32, 'flow': 31, 'shares': 31, 'Statement': 31, 'provide': 31, 'risks': 31, 'liability': 31, 'recognized': 31, 'acquired': 30, 'provided': 30, 'SEC': 30, 'Years': 30, '&': 29, 'Operating': 29, 'discussed': 29, 'Balance': 29, 'Cash': 29, 'flows': 29, 'company': 28, 'majority': 28, 'repurchases': 28, 'Stock': 28, 'herein': 28, 'various': 28, 'general': 28, 'charges': 28, 'claims': 28, 'programs': 27, 'international': 27, 'paid': 27, 'attributable': 27, 'annual': 26, 'within': 26, 'prior': 26, 'omni-channel': 26, 'derivatives': 26, 'counts': 26, 'follows': 26, 'Walmar˜': 25, 'systems': 25, 'operate': 25, 'investments': 25, 'Exchange': 25, 'whether': 25, 'estimates': 25, 'events': 25, 'club': 25, 'purchase': 25, 'goods': 25, 'legal': 25, 'sell': 25, 'payment': 25, 'Asda': 25, 'accumulated': 25, 'date': 25, 'available': 25, 'items': 24, 'digital': 24, 'use': 24, '15': 24, '12': 24, 'economic': 24, 'prices': 24, 'consumer': 24, '2016': 24, 'measure': 24, 'percentage': 24, 'local': 24, 'benefi ...
