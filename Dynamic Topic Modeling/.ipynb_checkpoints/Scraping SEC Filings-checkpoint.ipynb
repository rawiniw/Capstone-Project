# %%
#https://github.com/bozhang0504/Scraping-SEC-filings

import urllib, os
from bs4 import BeautifulSoup as BeautifulSoup
import pandas as pd

# Step 1: Define funtions to download filings
def get_list(ticker):

    base_url_part1 = "http://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK="
    base_url_part2 = "&type=&dateb=&owner=&start="
    base_url_part3 = "&count=100&output=xml"
    href = []
    
    for page_number in range(0,2000,100):
    
        base_url = base_url_part1 + ticker + base_url_part2 + str(page_number) + base_url_part3
        
        sec_page = urllib.request.urlopen(base_url)
        sec_soup = BeautifulSoup(sec_page)
        
        filings = sec_soup.findAll('filing')
        
        for filing in filings:
            report_year = int(filing.datefiled.get_text()[0:4])
            if (filing.type.get_text() == "10-K") & (report_year >= 2015):
                print (filing.filinghref.get_text())
                href.append(filing.filinghref.get_text())
    
    return href

def download_report(url_list,dir_path):
    
    target_base_url = 'http://www.sec.gov'
    
    # type = 'EX-101.INS'
    target_file_type = u'EX-101.INS'
    
    for report_url in url_list:
        report_page = urllib.request.urlopen(report_url)
        report_soup = BeautifulSoup(report_page)
        
        xbrl_file = report_soup.findAll('tr')
        
        for item in xbrl_file:
            try:
                if item.findAll('td')[3].get_text() == target_file_type:
                    if not os.path.exists(dir_path):
                        os.makedirs(dir_path)
                             
                    target_url = target_base_url + item.findAll('td')[2].find('a')['href']
                    print ("Target URL found!")
                    print ("Target URL is:", target_url)
                    
                    file_name = target_url.split('/')[-1]
                    print (file_name)
                   
                    xbrl_report = urllib2.urlopen(target_url)
                    output = open(os.path.join(dir_path,file_name),'wb')
                    output.write(xbrl_report.read())
                    output.close()
                    
            except:
                pass

# Step 2: Define funtions to download filings
Tickers = ["WMT","TGT","AMZN"]

for ticker in Tickers:
    url_list= get_list(ticker)
    base_path = "./Downloaded_Filings"
    dir_path = base_path + "/"+ticker
    download_report(url_list,dir_path)
# Out:
# https://www.sec.gov/Archives/edgar/data/104169/000010416919000016/0000104169-19-000016-index.htm
# https://www.sec.gov/Archives/edgar/data/104169/000010416918000028/0000104169-18-000028-index.htm
# https://www.sec.gov/Archives/edgar/data/104169/000010416917000021/0000104169-17-000021-index.htm
# https://www.sec.gov/Archives/edgar/data/104169/000010416916000079/0000104169-16-000079-index.htm
# https://www.sec.gov/Archives/edgar/data/104169/000010416915000011/0000104169-15-000011-index.htm
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/104169/000010416919000016/wmt-20190131.xml
# wmt-20190131.xml
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/104169/000010416918000028/wmt-20180131.xml
# wmt-20180131.xml
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/104169/000010416917000021/wmt-20170131.xml
# wmt-20170131.xml
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/104169/000010416916000079/wmt-20160131.xml
# wmt-20160131.xml
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/104169/000010416915000011/wmt-20150131.xml
# wmt-20150131.xml
# https://www.sec.gov/Archives/edgar/data/27419/000002741919000006/0000027419-19-000006-index.htm
# https://www.sec.gov/Archives/edgar/data/27419/000002741918000010/0000027419-18-000010-index.htm
# https://www.sec.gov/Archives/edgar/data/27419/000002741917000008/0000027419-17-000008-index.htm
# https://www.sec.gov/Archives/edgar/data/27419/000002741916000043/0000027419-16-000043-index.htm
# https://www.sec.gov/Archives/edgar/data/27419/000002741915000012/0000027419-15-000012-index.htm
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/27419/000002741919000006/tgt-20190202.xml
# tgt-20190202.xml
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/27419/000002741918000010/tgt-20180203.xml
# tgt-20180203.xml
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/27419/000002741917000008/tgt-20170128.xml
# tgt-20170128.xml
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/27419/000002741916000043/tgt-20160130.xml
# tgt-20160130.xml
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/27419/000002741915000012/tgt-20150131.xml
# tgt-20150131.xml
# https://www.sec.gov/Archives/edgar/data/1018724/000101872420000004/0001018724-20-000004-index.htm
# https://www.sec.gov/Archives/edgar/data/1018724/000101872419000004/0001018724-19-000004-index.htm
# https://www.sec.gov/Archives/edgar/data/1018724/000101872418000005/0001018724-18-000005-index.htm
# https://www.sec.gov/Archives/edgar/data/1018724/000101872417000011/0001018724-17-000011-index.htm
# https://www.sec.gov/Archives/edgar/data/1018724/000101872416000172/0001018724-16-000172-index.htm
# https://www.sec.gov/Archives/edgar/data/1018724/000101872415000006/0001018724-15-000006-index.htm
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/1018724/000101872419000004/amzn-20181231.xml
# amzn-20181231.xml
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/1018724/000101872418000005/amzn-20171231.xml
# amzn-20171231.xml
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/1018724/000101872417000011/amzn-20161231.xml
# amzn-20161231.xml
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/1018724/000101872416000172/amzn-20151231.xml
# amzn-20151231.xml
# Target URL found!
# Target URL is: http://www.sec.gov/Archives/edgar/data/1018724/000101872415000006/amzn-20141231.xml
# amzn-20141231.xml
